# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/DuyNguyen25092004/PBL4_Aritificial_Intelligent.git
# Out:
# Cloning into 'PBL4_Aritificial_Intelligent'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 98 (delta 34), reused 85 (delta 26), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 1.56 MiB | 43.21 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# %cd /content/PBL4_Aritificial_Intelligent/IMLE-Net
# !pip install -r requirements.txt
# Out:
# /content/PBL4_Aritificial_Intelligent/IMLE-Net
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 20.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 156.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# ...

# %%
# !cp -r /content/drive/MyDrive/IMLE-Net-Project/data/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.1.zip /content/PBL4_Aritificial_Intelligent/IMLE-Net/data/ptb.zip

# %%
# %cd /content/PBL4_Aritificial_Intelligent/IMLE-Net/data
# !unzip -q ptb.zip -d .
# !mv /content/PBL4_Aritificial_Intelligent/IMLE-Net/data/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.1 /content/PBL4_Aritificial_Intelligent/IMLE-Net/data/ptb
# Out:
# /content/PBL4_Aritificial_Intelligent/IMLE-Net/data

# %%
# %cd /content/PBL4_Aritificial_Intelligent/IMLE-Net
# !python train.py --model imle_net --batchsize 32 --epochs 10 --loggr False
# Out:
# /content/PBL4_Aritificial_Intelligent/IMLE-Net
# 2026-01-13 12:19:50.717446: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768306790.739325   25931 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768306790.745989   25931 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768306790.763829   25931 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !cp -r /content/drive/MyDrive/IMLE-Net-Project/results/imle_net_20260114_014533/checkpoints /content/PBL4_Aritificial_Intelligent/IMLE-Net/checkpoints

# %%
#train the trained model

# %cd /content/PBL4_Aritificial_Intelligent/IMLE-Net
# !python resume_train.py --model imle_net --batchsize 16 --epochs 7 --loggr False
# Out:
# /content/PBL4_Aritificial_Intelligent/IMLE-Net
# 2026-01-14 01:50:39.829188: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768355439.852099   39340 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768355439.858274   39340 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768355439.878419   39340 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
#save model's weigth to google drive
# !python save_to_drive.py --model imle_net
# Out:
# ...
# SAVING RESULTS TO GOOGLE DRIVE
# ...
# Destination: /content/drive/MyDrive/IMLE-Net-Project/results/imle_net_20260114_022014
#
# 📦 Saving checkpoints...
# Traceback (most recent call last):
#   File "/content/PBL4_Aritificial_Intelligent/IMLE-Net/save_to_drive.py", line 260, in <module>
#     save_to_drive(
#   File "/content/PBL4_Aritificial_Intelligent/IMLE-Net/save_to_drive.py", line 75, in save_to_drive
#     shutil.copy2(src, dst)
#   File "/usr/lib/python3.12/shutil.py", line 475, in copy2
#     copyfile(src, dst, follow_symlinks=follow_symlinks)
#   File "/usr/lib/python3.12/shutil.py", line 260, in copyfile
#     with open(src, 'rb') as fsrc:
#          ^^^^^^^^^^^^^^^
# IsADirectoryError: [Errno 21] Is a directory: '/content/PBL4_Aritificial_Intelligent/IMLE-Net/checkpoints/imle_net_20260114_014533'
